# %%
import pandas as pd

# %%
df=pd.read_csv('dataset_Facebook.csv', sep=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
op1=df.loc[0:50, ['Type', 'Post Weekday', 'Post Hour','like', 'share']]

# %%
op3=df[df['Post Hour']>3]

# %%
op1=op1.sort_values(by=['like', 'share'], ascending=False)
op1
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 3    Photo             2         10  1572.0  147.0
# 17   Photo             2         12   678.0   20.0
# 14   Photo             4          5   577.0   20.0
# 28   Photo             5          3   523.0   63.0
# 26  Status             5         11   412.0   72.0
# 4    Photo             2          3   325.0   49.0
# 7    Photo             7          9   325.0   14.0
# 6    Photo             1          3   249.0   27.0
# 10  Status             5         10   233.0   19.0
# 38  Status             7          9   227.0   31.0
# 40  Status             6         11   216.0   39.0
# 41    Link             6          3   187.0   18.0
# 46  Status             3         11   174.0   36.0
# 35   Photo             1         11   172.0   21.0
# 8   Status             7          3   161.0   31.0
# 32   Photo             3          3   155.0   47.0
# 5   Status             1          9   152.0   33.0
# ...

# %%
df_subset1=df.loc[0:4, ['Post Month', 'comment', 'like', 'share']]
df_subset1.head()

# %%
df_subset2=df.iloc[5:10, [3, 4, 5, 6, 7]]
df_subset2.head()

# %%
df_subset3=df['like'].div(df['share']).to_frame('like-share-ratio')
df_subset3.head()

# %%
df_merged=pd.merge(df, df_subset3, left_index=True, right_index=True)
df_merged.head()

# %%
df_sorted=df.sort_values(by=['Page total likes', 'comment', 'like'], ascending=False)
df_sorted.head()

# %%
df_shape=df.shape
print(df_shape)

# %%
df_reshape=df.pivot(columns='Type', values='like')
df_reshape.tail()
